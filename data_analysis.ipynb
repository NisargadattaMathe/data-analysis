# %% [markdown]
# # Challenge 1

# %%
import os
import json
import urllib.request
import requests
import csv
import pandas as pd

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv('CAvideos.csv',index_col = 'video_id')

# %% [markdown]
# ## Preprocessing the data

# %%
#removing the column named "thumbnail_link" as it will not be used for the analysis.
df = df.drop(['thumbnail_link'],axis = 1)
df.head()
# Out:
#             trending_date                                              title  \
# video_id
# n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# 2Vv-BfVoq4g      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#             channel_title  category_id              publish_time  \
# video_id
# n1WpP7iowLc    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 0dBIkQ4Mz1M     iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 5qpjK5DgCt4  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# d380meD0W0M      nigahiga           24  2017-11-12T18:01:41.000Z
# 2Vv-BfVoq4g    Ed Sheeran           10  2017-11-09T11:04:14.000Z
#
#                                                           tags     views  \
# video_id
# ...

# %%
df.shape
# Out:
# (40881, 14)

# %%
df['LikesPerView'] = df['likes']/df['views']

# %%
df.head()
# Out:
#             trending_date                                              title  \
# video_id
# n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# 2Vv-BfVoq4g      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#             channel_title  category_id              publish_time  \
# video_id
# n1WpP7iowLc    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 0dBIkQ4Mz1M     iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 5qpjK5DgCt4  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# d380meD0W0M      nigahiga           24  2017-11-12T18:01:41.000Z
# 2Vv-BfVoq4g    Ed Sheeran           10  2017-11-09T11:04:14.000Z
#
#                                                           tags     views  \
# video_id
# ...

# %%
df["views_mean"] = ((df["views"]-df["views"].min())/(df["views"].max()-df["views"].min()))*100
df["likes_mean"] = ((df["likes"]-df["likes"].min())/(df["likes"].max()-df["likes"].min()))*100
df["dislikes_mean"] = ((df["dislikes"]-df["dislikes"].min())/(df["dislikes"].max()-df["dislikes"].min()))*100

# %%
df.head()
# Out:
#             trending_date                                              title  \
# video_id
# n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# 2Vv-BfVoq4g      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#             channel_title  category_id              publish_time  \
# video_id
# n1WpP7iowLc    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 0dBIkQ4Mz1M     iDubbbzTV           23  2017-11-13T17:00:00.000Z
# 5qpjK5DgCt4  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# d380meD0W0M      nigahiga           24  2017-11-12T18:01:41.000Z
# 2Vv-BfVoq4g    Ed Sheeran           10  2017-11-09T11:04:14.000Z
#
#                                                           tags     views  \
# video_id
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()
df.plot("views_mean","likes_mean")
plt.title("Views vs Likes")
plt.xlabel("Total Views")
plt.ylabel("Total Likes")
plt.show()
